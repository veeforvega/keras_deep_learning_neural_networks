# %% [markdown]
# #### C. Increate the number of epochs (5 marks)
#
# Repeat Part B but use <strong>100 epochs</strong> this time for training.

# %% [markdown]
# # Regression Models with Keras (Normalized)

# %% [markdown]
# Start by importing the pandas, Keras, Numpy libraries.

# %%
import pandas as pd
import numpy as np
import keras 

import warnings
warnings.simplefilter('ignore', FutureWarning)
# Out:
# 2025-02-05 02:54:08.477635: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# #### Download the data and read it into a <em>pandas</em> dataframe.

# %%
filepath = 'https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv'
concrete_data = pd.read_csv(filepath)

concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# #### Split data into predictors and target

# %% [markdown]
# The target variable in this problem is the concrete sample strength. Therefore, our predictors will be all the other columns.

# %%
concrete_data_columns = concrete_data.columns

# %%
predictors = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']] # all columns except Strength
target = concrete_data['Strength'] # Strength column

# %% [markdown]
# Normalize the data by substracting the mean and dividing by the standard deviation. (Part B)

# %%
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %% [markdown]
# ##  Import Keras Packages
#
# ##### Import the rest of the packages from the Keras library that will be needed to build regression model.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Input

# %% [markdown]
# ## Build a Neural Network
#
# I will create a function that defines our regression model's requirements for Part A so that I can conveniently call it to create our model.

# %% [markdown]
# ### A. Build a baseline model
#
# Use the Keras library to build a neural network with the following:
#
# - One hidden layer of 10 nodes, and a ReLU activation function
#
# - Use the adam optimizer and the mean squared error  as the loss function.

# %%
# define regression model
def regression_model(n_cols):
    # create model
    model = Sequential()
    model.add(Dense(10, activation='relu', input_shape=(n_cols,)))
    model.add(Dense(1))
    
    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# The above function creates a model that has one hidden layer with 10 neurons and a ReLU activation function. It uses the adam optimizer and the mean squared error as the loss function.

# %% [markdown]
# ### Import scikit-learn in order to randomly split the data into a training and test sets
#
# 1. Randomly split the data into a training and test sets by holding 30% of the data for testing. You can use the train_test_split helper function from Scikit-learn.
#
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
X_train, X_test, y_train, y_test = train_test_split(predictors_norm, target, test_size=0.3, random_state=42) #random_state set based on example from scikit-learn doc

# Standardize the features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Train and Test the Network

# %% [markdown]
# Call the function now to create our model.

# %%
# build the model
model = regression_model(predictors_norm.shape[1])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# Now train the model based on the requirements.
#
# 2. Train the model on the training data using 100 epochs.

# %%
# fit the model
epochs = 100 # Part C
model.fit(X_train, y_train, epochs=epochs, verbose=2)
# Out:
# Epoch 1/100
# 23/23 - 1s - 34ms/step - loss: 1576.3040
# Epoch 2/100
# 23/23 - 0s - 3ms/step - loss: 1559.4011
# Epoch 3/100
# 23/23 - 0s - 3ms/step - loss: 1542.5269
# Epoch 4/100
# 23/23 - 0s - 3ms/step - loss: 1525.6543
# Epoch 5/100
# 23/23 - 0s - 3ms/step - loss: 1508.0175
# Epoch 6/100
# 23/23 - 0s - 3ms/step - loss: 1490.4688
# Epoch 7/100
# 23/23 - 0s - 3ms/step - loss: 1471.8433
# Epoch 8/100
# 23/23 - 0s - 3ms/step - loss: 1452.6473
# Epoch 9/100
# 23/23 - 0s - 3ms/step - loss: 1432.7744
# Epoch 10/100
# 23/23 - 0s - 3ms/step - loss: 1411.6111
# Epoch 11/100
# 23/23 - 0s - 3ms/step - loss: 1390.3352
# Epoch 12/100
# 23/23 - 0s - 3ms/step - loss: 1367.9323
# Epoch 13/100
# 23/23 - 0s - 3ms/step - loss: 1344.6268
# Epoch 14/100
# 23/23 - 0s - 4ms/step - loss: 1320.4257
# Epoch 15/100
# 23/23 - 0s - 4ms/step - loss: 1295.2581
# Epoch 16/100
# 23/23 - 0s - 3ms/step - loss: 1269.9954
# Epoch 17/100
# 23/23 - 0s - 3ms/step - loss: 1243.8082
# Epoch 18/100
# 23/23 - 0s - 3ms/step - loss: 1216.7214
# Epoch 19/100
# 23/23 - 0s - 3ms/step - loss: 1189.0980
# Epoch 20/100
# 23/23 - 0s - 4ms/step - loss: 1160.6787
# Epoch 21/100
# 23/23 - 0s - 5ms/step - loss: 1131.7053
# Epoch 22/100
# 23/23 - 0s - 4ms/step - loss: 1102.0385
# Epoch 23/100
# 23/23 - 0s - 5ms/step - loss: 1072.3595
# Epoch 24/100
# 23/23 - 0s - 4ms/step - loss: 1041.8577
# Epoch 25/100
# 23/23 - 0s - 3ms/step - loss: 1011.4000
# Epoch 26/100
# 23/23 - 0s - 11ms/step - loss: 979.7925
# Epoch 27/100
# Epoch 69/100
# 23/23 - 0s - 5ms/step - loss: 247.3616
# Epoch 70/100
# 23/23 - 0s - 3ms/step - loss: 241.3692
# Epoch 71/100
# 23/23 - 0s - 3ms/step - loss: 235.6857
# Epoch 72/100
# 23/23 - 0s - 4ms/step - loss: 230.1772
# Epoch 73/100
# 23/23 - 0s - 4ms/step - loss: 225.1531
# Epoch 74/100
# 23/23 - 0s - 4ms/step - loss: 220.1178
# Epoch 75/100
# 23/23 - 0s - 3ms/step - loss: 215.4659
# Epoch 76/100
# 23/23 - 0s - 3ms/step - loss: 211.1326
# Epoch 77/100
# 23/23 - 0s - 3ms/step - loss: 206.7971
# Epoch 78/100
# 23/23 - 0s - 3ms/step - loss: 202.7101
# Epoch 79/100
# 23/23 - 0s - 3ms/step - loss: 198.9716
# Epoch 80/100
# 23/23 - 0s - 4ms/step - loss: 195.3210
# Epoch 81/100
# 23/23 - 0s - 4ms/step - loss: 191.9590
# Epoch 82/100
# 23/23 - 0s - 5ms/step - loss: 188.7091
# Epoch 83/100
# 23/23 - 0s - 4ms/step - loss: 185.6753
# Epoch 84/100
# 23/23 - 0s - 3ms/step - loss: 182.9262
# Epoch 85/100
# 23/23 - 0s - 4ms/step - loss: 180.2037
# Epoch 86/100
# 23/23 - 0s - 4ms/step - loss: 177.6522
# Epoch 87/100
# 23/23 - 0s - 4ms/step - loss: 175.1286
# Epoch 88/100
# 23/23 - 0s - 4ms/step - loss: 172.9190
# Epoch 89/100
# 23/23 - 0s - 3ms/step - loss: 170.8139
# Epoch 90/100
# 23/23 - 0s - 3ms/step - loss: 168.6840
# Epoch 91/100
# 23/23 - 0s - 3ms/step - loss: 166.7899
# Epoch 92/100
# 23/23 - 0s - 3ms/step - loss: 164.9600
# Epoch 93/100
# 23/23 - 0s - 3ms/step - loss: 163.2479
# Epoch 94/100
# 23/23 - 0s - 3ms/step - loss: 161.5524
# Epoch 95/100
# 23/23 - 0s - 3ms/step - loss: 160.0719
# Epoch 96/100
# 23/23 - 0s - 3ms/step - loss: 158.6678
# Epoch 97/100
# 23/23 - 0s - 5ms/step - loss: 157.2238
# Epoch 98/100
# 23/23 - 0s - 3ms/step - loss: 155.8535
# Epoch 99/100
# 23/23 - 0s - 3ms/step - loss: 154.5885
# Epoch 100/100
# 23/23 - 0s - 3ms/step - loss: 153.3449

# %% [markdown]
# Next evaluate the model on the test data according the requirements #3.
#
#
# 3. Evaluate the model on the test data and compute the mean squared error between the predicted concrete strength and the actual concrete strength. You can use the mean_squared_error function from Scikit-learn.

# %%
model_eval = model.evaluate(X_test, y_test)
y_pred = model.predict(X_test)
model_eval
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 147.3090
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 151.6009063720703

# %% [markdown]
# Now compute the mean squared error between the predicted concrete strength and the actual concrete strength.

# %% [markdown]
# Import the mean_squared_error function from Scikit-learn.

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_square_error = mean_squared_error(y_test, y_pred)
mean_mse = np.mean(mean_square_error)
standard_deviation_mse = np.std(mean_square_error)

print(f'Mean Square Error: {mean_square_error}')
print(f'Mean : {mean_mse}\nStandard Deviation: {standard_deviation_mse}')
# Out:
# Mean Square Error: 151.60090894467402
# Mean : 151.60090894467402
# Standard Deviation: 0.0

# %% [markdown]
# Finally finish the last requirements
#
# 4. Repeat steps 1 - 3, 50 times, i.e., create a list of 50 mean squared errors.
# 5. Report the mean and the standard deviation of the mean squared errors.

# %%
mean_squared_errors = []

scaler = StandardScaler()

for i in range(1, 51):
    X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.3, random_state=i)
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    model.fit(X_train, y_train, epochs=epochs, verbose=0)
    model_eval = model.evaluate(X_test, y_test)
    print(f'Model evaluation {i}: {model_eval}')
    y_pred = model.predict(X_test)
    mean_square_error = mean_squared_error(y_test, y_pred)
    mean_squared_errors.append(mean_square_error)

mean_squared_errors = np.array(mean_squared_errors)
mean_mse = np.mean(mean_squared_errors)
standard_deviation_mse = np.std(mean_squared_errors)

print(f'Mean : {mean_mse}\nStandard Deviation: {standard_deviation_mse}')
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 100.3502
# Model evaluation 1: 104.20365905761719
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 70.6554
# Model evaluation 2: 74.17737579345703
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 63.0692
# Model evaluation 3: 62.92905044555664
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 51.6683
# Model evaluation 4: 47.350013732910156
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 50.3571
# Model evaluation 5: 48.891719818115234
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 41.7384
# Model evaluation 6: 46.27328109741211
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 32.5592
# Model evaluation 7: 34.243919372558594
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 36.7688
# Model evaluation 8: 36.05762481689453
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 33.1506
# Model evaluation 9: 35.61975860595703
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 33.5824
# Model evaluation 10: 37.63949966430664
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 32.1273
# Model evaluation 11: 32.91891860961914
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 42.5549
# Model evaluation 12: 40.11316680908203
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 45.4850
# Model evaluation 13: 41.6026725769043
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 33.1697
# Model evaluation 14: 34.84273147583008
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.0173
# Model evaluation 15: 30.418954849243164
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 39.1695
# Model evaluation 16: 38.20132827758789
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 40.3056
# Model evaluation 17: 35.623573303222656
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 34.5688
# Model evaluation 18: 34.5720100402832
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 40.9122
# Model evaluation 19: 37.43146514892578
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 33.8171
# Model evaluation 20: 32.49545669555664
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 37.0263
# Model evaluation 21: 32.405513763427734
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.0585
# Model evaluation 22: 29.278547286987305
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 35.5810
# Model evaluation 23: 31.393848419189453
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 35.7714
# Model evaluation 24: 36.58784866333008
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 32.8760
# Model evaluation 25: 36.531578063964844
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 33.2473
# Model evaluation 26: 32.30340576171875
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 39.9501
# Model evaluation 27: 36.47591018676758
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 34.7986
# Model evaluation 28: 39.29819107055664
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 35.3789
# Model evaluation 29: 36.87639236450195
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 37.9892
# Model evaluation 30: 33.523006439208984
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 31.2996
# Model evaluation 31: 32.257930755615234
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 33.0110
# Model evaluation 32: 30.525442123413086
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 40.2906
# Model evaluation 33: 37.26874923706055
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 32.2893
# Model evaluation 34: 36.92639923095703
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 46.3549
# Model evaluation 35: 41.085121154785156
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.6687
# Model evaluation 36: 30.25800132751465
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 39.5382
# Model evaluation 37: 37.29617691040039
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 39.0602
# Model evaluation 38: 34.61035919189453
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 31.2528
# Model evaluation 39: 29.270071029663086
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 36.4870
# Model evaluation 40: 37.35759735107422
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 33.0458
# Model evaluation 41: 31.685787200927734
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 31.0945
# Model evaluation 42: 33.190391540527344
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 36.6924
# Model evaluation 43: 39.2427978515625
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 33.2667
# Model evaluation 44: 37.75243377685547
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 39.1055
# Model evaluation 45: 37.58805847167969
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 32.4083
# Model evaluation 46: 35.66668701171875
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 40.4074
# Model evaluation 47: 37.81435775756836
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 36.4906
# Model evaluation 48: 34.911617279052734
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 36.2791
# Model evaluation 49: 37.03465270996094
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.1081
# Model evaluation 50: 32.96205139160156
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Mean : 38.69970177362311
# Standard Deviation: 12.094020399563561

# %%
concrete_data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %% [markdown]
# How does the mean of the mean squared errors compare to that from Step B?
#
#
# <strong> Step (B) </strong>
#
# Mean : 46.54254830788286
# Standard Deviation: 26.353768700723307
#
# <strong> Step (C) </strong>
#
# Mean : 38.69970177362311
# Standard Deviation: 12.094020399563561
#
# The mean for step C was a lot closer to the actually mean of the concrete data.
